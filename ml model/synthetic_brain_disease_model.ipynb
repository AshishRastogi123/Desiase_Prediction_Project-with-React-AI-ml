# %%
import pandas as pd

# %%
df=pd.read_csv('synthetic_brain_disease_dataset.csv')

# %%
df
# Out:
#       Age  Gender Ethnicity Education_Level Family_History Memory_Loss  \
# 0      69     NaN     Other             NaN            Yes          No
# 1      32  Female     Other             PhD            NaN          No
# 2      89   Other     Asian             NaN             No         Yes
# 3      78   Other     Other             NaN             No         Yes
# 4      38    Male     White             PhD            Yes         Yes
# ...   ...     ...       ...             ...            ...         ...
# 7995   72  Female     Asian             NaN             No          No
# 7996   32    Male     Asian       Bachelors            Yes         Yes
# 7997   89    Male     Black         Masters            Yes          No
# 7998   51    Male     Other             PhD             No         Yes
# 7999   19    Male     White       Bachelors            Yes         Yes
#
#      Seizures Headaches Vision_Problems Mood_Changes Hypertension Diabetes  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Ethnicity', 'Education_Level', 'Family_History',
#        'Memory_Loss', 'Seizures', 'Headaches', 'Vision_Problems',
#        'Mood_Changes', 'Hypertension', 'Diabetes', 'Heart_Disease',
#        'Previous_Stroke', 'Brain_Injury', 'MMSE_Score', 'UPDRS_Score',
#        'MRI_Abnormality', 'Tumor_Size_cm', 'Diagnosis'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              8000 non-null   int64
#  1   Gender           7600 non-null   object
#  2   Ethnicity        8000 non-null   object
#  3   Education_Level  6281 non-null   object
#  4   Family_History   7225 non-null   object
#  5   Memory_Loss      8000 non-null   object
#  6   Seizures         8000 non-null   object
#  7   Headaches        7600 non-null   object
#  8   Vision_Problems  8000 non-null   object
#  9   Mood_Changes     7600 non-null   object
#  10  Hypertension     8000 non-null   object
#  11  Diabetes         8000 non-null   object
#  12  Heart_Disease    8000 non-null   object
#  13  Previous_Stroke  7600 non-null   object
#  14  Brain_Injury     8000 non-null   object
#  15  MMSE_Score       8000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender              400
# Ethnicity             0
# Education_Level    1719
# Family_History      775
# Memory_Loss           0
# Seizures              0
# Headaches           400
# Vision_Problems       0
# Mood_Changes        400
# Hypertension          0
# Diabetes              0
# Heart_Disease         0
# Previous_Stroke     400
# Brain_Injury          0
# MMSE_Score            0
# UPDRS_Score           0
# MRI_Abnormality     817
# Tumor_Size_cm         0
# Diagnosis           400
# dtype: int64

# %% [markdown]
# ### #we will fill all nan values escape  Diagnosis

# %%
df['Gender']=df['Gender'].fillna('Unknown')
df['Education_Level']=df['Education_Level'].fillna('Not Given')
df['Headaches']=df['Headaches'].fillna('No')
df['Mood_Changes']=df['Mood_Changes'].fillna('No')
df['Mood_Changes']=df['Mood_Changes'].fillna('No')
df['Previous_Stroke']=df['Previous_Stroke'].fillna('No')
df['MRI_Abnormality']=df['MRI_Abnormality'].fillna('No')

# %%
df['Family_History']=df['Family_History'].fillna('No')

# %%
df = df.dropna(subset=['Diagnosis'])

# %%
df.isnull().sum()
# Out:
# Age                0
# Gender             0
# Ethnicity          0
# Education_Level    0
# Family_History     0
# Memory_Loss        0
# Seizures           0
# Headaches          0
# Vision_Problems    0
# Mood_Changes       0
# Hypertension       0
# Diabetes           0
# Heart_Disease      0
# Previous_Stroke    0
# Brain_Injury       0
# MMSE_Score         0
# UPDRS_Score        0
# MRI_Abnormality    0
# Tumor_Size_cm      0
# Diagnosis          0
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include="object").columns
categorical_cols
# Out:
# Index(['Gender', 'Ethnicity', 'Education_Level', 'Family_History',
#        'Memory_Loss', 'Seizures', 'Headaches', 'Vision_Problems',
#        'Mood_Changes', 'Hypertension', 'Diabetes', 'Heart_Disease',
#        'Previous_Stroke', 'Brain_Injury', 'MRI_Abnormality', 'Diagnosis'],
#       dtype='object')

# %%
numeric_cols = df.select_dtypes(include="number").columns
numeric_cols
# Out:
# Index(['Age', 'MMSE_Score', 'UPDRS_Score', 'Tumor_Size_cm'], dtype='object')

# %% [markdown]
# ## #Perorm Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
for col in categorical_cols:
    df[col] = encoder.fit_transform(df[col])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(16, 10))
sns.heatmap(df.corr(), cmap="coolwarm", annot=True)
plt.title("Feature Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## #Prepare data for training

# %%
x = df.drop("Previous_Stroke", axis=1)
y = df["Previous_Stroke"]

# %% [markdown]
# ## #Train/test split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## #Train Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ## #Evaluate the model

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
y_pred = model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

# %%
print("Model Accuracy:", accuracy)
print("Classification Report:\n", report)
# Out:
# Model Accuracy: 0.5243421052631579
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.65      0.59       796
#            1       0.50      0.38      0.43       724
#
#     accuracy                           0.52      1520
#    macro avg       0.52      0.52      0.51      1520
# weighted avg       0.52      0.52      0.52      1520
